# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # For density plots

# Generate some example data (replace this with your actual data)
np.random.seed(0)
data = np.random.normal(loc=0, scale=1, size=1000)

# Create a histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.hist(data, bins=30, edgecolor='black', alpha=0.7)
plt.title('Histogram')

# Create a box plot
plt.subplot(1, 3, 2)
plt.boxplot(data, vert=False)
plt.title('Box Plot')

# Create a density plot
plt.subplot(1, 3, 3)
sns.kdeplot(data, shade=True)
plt.title('Density Plot')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_16536\955113159.py:22: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(data, shade=True)

# %%
# Generate skewed data
np.random.seed(0)
skewed_data = np.random.exponential(scale=2, size=1000) + 5

# Create a histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.hist(skewed_data, bins=30, edgecolor='black', alpha=0.7)
plt.title('Histogram')

# Create a box plot
plt.subplot(1, 3, 2)
plt.boxplot(skewed_data, vert=False)
plt.title('Box Plot')

# Create a density plot
plt.subplot(1, 3, 3)
sns.kdeplot(skewed_data, shade=True)
plt.title('Density Plot')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_16536\2794230346.py:18: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(skewed_data, shade=True)

# %%
# Generate left-skewed data
np.random.seed(0)
left_skewed_data = -np.random.exponential(scale=2, size=1000) + 5

# Create a histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.hist(left_skewed_data, bins=30, edgecolor='black', alpha=0.7)
plt.title('Histogram')

# Create a box plot
plt.subplot(1, 3, 2)
plt.boxplot(left_skewed_data, vert=False)
plt.title('Box Plot')

# Create a density plot
plt.subplot(1, 3, 3)
sns.kdeplot(left_skewed_data, shade=True)
plt.title('Density Plot')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\bhupe\AppData\Local\Temp\ipykernel_16536\655669290.py:18: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(left_skewed_data, shade=True)

# %% [markdown]
# #### income distribution,
#
# - which is typically right-skewed because a small percentage of the population earns significantly higher incomes compared to the majority.

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Generate synthetic income data with right-skew
np.random.seed(42)
income_data = np.random.exponential(scale=3000, size=1000)

# %%
# Visualize the income distribution
plt.figure(figsize=(8, 6))
sns.histplot(income_data, kde=True)
plt.title('Income Distribution (Right-skewed)')
plt.xlabel('Income')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# #### Wealth Distribution (Right-skewed):
#
# - Just like income distribution, wealth distribution is often right-skewed, where a small percentage of the population holds a significant portion of the total wealth.

# %%
# Generate synthetic wealth data with right-skew
np.random.seed(42)
wealth_data = np.random.exponential(scale=500000, size=1000)

# Visualize the wealth distribution
plt.figure(figsize=(8, 6))
sns.histplot(wealth_data, kde=True)
plt.title('Wealth Distribution (Right-skewed)')
plt.xlabel('Wealth')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# ##### Company Profits (Right-skewed):
#
# - Company profit distributions can also be right-skewed, as a few successful companies might earn significantly higher profits compared to the majority.

# %%
# Generate synthetic company profit data with right-skew
np.random.seed(42)
profit_data = np.random.exponential(scale=1000000, size=1000)

# Visualize the company profit distribution
plt.figure(figsize=(8, 6))
sns.histplot(profit_data, kde=True)
plt.title('Company Profit Distribution (Right-skewed)')
plt.xlabel('Profit')
plt.ylabel('Frequency');

# %% [markdown]
# ##### Inflation Rates (Left-skewed):
#
# - Inflation rates often exhibit left-skewness because extreme deflation is rarer compared to moderate inflation.

# %%
# Generate synthetic inflation rate data with left-skew
np.random.seed(42)
inflation_data = -np.random.exponential(scale=1, size=1000)

# Visualize the inflation rate distribution
plt.figure(figsize=(8, 6))
sns.histplot(inflation_data, kde=True)
plt.title('Inflation Rate Distribution (Left-skewed)')
plt.xlabel('Inflation Rate')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %% [markdown]
# #### Kurtosis

# %%
import numpy as np
from scipy.stats import kurtosis

# %%
# Create a sample dataset
data = np.array([1, 2, 2, 3, 4, 5, 6, 7, 8, 9])

# %%
# Calculate the kurtosis
data_kurtosis = kurtosis(data)

print("Kurtosis:", data_kurtosis)
# Out:
# Kurtosis: -1.2887370865596717

# %% [markdown]
# #### plot 3 types of kurtosis distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import norm, t

# %%
# Generate data for different kurtosis distributions
x = np.linspace(-5, 5, 1000)

# Mesokurtic distribution (Normal distribution)
mesokurtic = norm.pdf(x, 0, 1)

# Leptokurtic distribution
leptokurtic = t.pdf(x, 3)

# Platykurtic distribution
platykurtic = np.exp(-x**2)

# %%
# Plot the distributions
plt.figure(figsize=(10, 6))
plt.plot(x, mesokurtic, label='Mesokurtic (Normal)')
plt.plot(x, leptokurtic, label='Leptokurtic')
plt.plot(x, platykurtic, label='Platykurtic')
plt.xlabel('Value')
plt.ylabel('Probability Density')
plt.title('Types of Kurtosis Distributions')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# `Mesokurtic Distribution (Normal Distribution)`:
# This is the standard normal distribution with zero mean and unit variance.
#
# `Leptokurtic Distribution:`
# We use the Student's t-distribution with degrees of freedom equal to 3. This distribution has heavier tails and is more peaked compared to the normal distribution.
#
# `Platykurtic Distribution:`
# We create a distribution that is exponentially decreasing, resulting in lighter tails compared to the normal distribution.

# %% [markdown]
# #### Leptokurtic distributions
#
# - have `heavier tails` and are `more peaked than the normal distribution`.
# - This can sometimes be an indicator of the presence of outliers, as extreme values in the tails of the distribution can lead to higher kurtosis values

# %% [markdown]
# ##### Example
# Let's generate a dataset with both a normal distribution and a leptokurtic distribution, and then we'll introduce some outliers

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import kurtosis

# %%
# Seed for reproducibility
np.random.seed(42)

# %%
# Generate normal distribution
normal_data = np.random.normal(0, 1, 1000)

# %%
# Generate leptokurtic distribution
leptokurtic_data = np.random.standard_t(3, 1000)

# %%
# Introduce outliers to leptokurtic distribution
leptokurtic_data_outliers = np.concatenate((leptokurtic_data, [20, -20]))

# %%
# Calculate kurtosis
normal_kurt      = kurtosis(normal_data)
leptokurtic_kurt = kurtosis(leptokurtic_data)

leptokurtic_kurt_outliers = kurtosis(leptokurtic_data_outliers)

# %%
# Plot the distributions
plt.figure(figsize=(12, 6))

plt.subplot(1, 2, 1)
plt.hist(normal_data, bins=30, color='blue', alpha=0.7, label='Normal')
plt.hist(leptokurtic_data,          bins=30, color='orange', alpha=0.7, label='Leptokurtic')
plt.hist(leptokurtic_data_outliers, bins=30, color='red', alpha=0.3,   label='Leptokurtic outliers')

plt.xlabel('Value')
plt.ylabel('Frequency')
plt.title('Distributions')
plt.legend()

plt.subplot(1, 2, 2)
plt.boxplot([normal_data, leptokurtic_data, leptokurtic_data_outliers], labels=['Normal', 'Leptokurtic', 'Leptokurtic with Outliers'])
plt.ylabel('Value')
plt.title('Boxplot')

plt.tight_layout()
plt.show()

print("Kurtosis - Normal:", normal_kurt)
print("Kurtosis - Leptokurtic:", leptokurtic_kurt)
print("Kurtosis - Leptokurtic with Outliers:", leptokurtic_kurt_outliers)
# Out:
# Kurtosis - Normal: 0.06620589292148393
# Kurtosis - Leptokurtic: 37.968824378485266
# Kurtosis - Leptokurtic with Outliers: 44.37041169005953

# %% [markdown]
# - we generate a `normal distribution` (normal_data) and `a leptokurtic distribution `(leptokurtic_data).
# - We then introduce outliers to the `leptokurtic distribution` (leptokurtic_data_outliers).
#
# - The boxplot and histograms help visualize the distributions.
#
# - notice that the `leptokurtic distribution is more peaked` than the normal distribution.
#
# - When outliers are introduced to the leptokurtic distribution, the tails become even heavier, leading to an even higher kurtosis value.

# %% [markdown]
# Now, let's compare this with the IQR method for outlier detection:

# %%
def find_outliers_iqr(data):
    Q1 = np.percentile(data, 25)
    Q3 = np.percentile(data, 75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    outliers = [x for x in data if x < lower_bound or x > upper_bound]
    return outliers

# %%
# Find outliers using IQR method
leptokurtic_outliers_iqr = find_outliers_iqr(leptokurtic_data_outliers)

print("Outliers using IQR:", leptokurtic_outliers_iqr)
# Out:
# Outliers using IQR: [5.089870058587585, 3.1693251700229776, -4.240839051922072, 4.610968110047192, -3.9363820274270553, -3.4652516416137296, -3.3448012461742374, 6.039375828944419, -6.003863202495093, 8.0644234310817, 3.5819753008142543, -3.56847945388857, -5.345066477544569, 3.5521119457427894, -3.865790530464156, -3.2824513863026357, -5.394667597668539, -3.3881636609686407, -3.617125642111772, 3.1901143272533763, 3.836502123940943, -8.352938550135034, 3.5415320351136845, 3.12256654522201, -5.249145866987809, 4.078607595060698, 7.395265605677664, -7.620012954324145, -3.4311124192975964, 3.1185242713254926, 3.171180298120559, -8.037340043839437, -6.362443465090106, -11.656150994139436, 4.150075897340896, -4.785753663732499, 3.52887535169704, 23.783840388060373, -3.2742477376605303, -3.8302128811773835, -3.865385717707339, 3.3935628421851805, 3.228141607321495, 3.4592853731280298, -4.889602025047248, 4.2403340316240214, 4.334597845124825, 3.3363952890766893, -4.754722826717486, 3.6972
# ...

# %% [markdown]
# #### let us take CA housing dataset and plot the columns KDE and compute kurtosis

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing
from scipy.stats import kurtosis

# %%
# Load California housing dataset
data = fetch_california_housing()
X, feature_names = data.data, data.feature_names

# %%
# Create KDE plots and compute kurtosis
plt.figure(figsize=(15, 10))

for i in range(X.shape[1]):
    plt.subplot(3, 3, i + 1)
    sns.kdeplot(X[:, i], label=feature_names[i])
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.title('KDE Plot - ' + feature_names[i])
    plt.legend()

    # Compute kurtosis
    kurt = kurtosis(X[:, i])
    plt.text(0.95, 0.85, f'Kurtosis: {kurt:.2f}', transform=plt.gca().transAxes, verticalalignment='top', horizontalalignment='right')

plt.tight_layout()

# %% [markdown]
# **MedInc (Median Income):**
#
# - The distribution appears to be positively skewed, which is typical for income data.
# - The kurtosis value is likely to be higher than for a normal distribution due to the heavy tail on the right side.
#
# **HouseAge (Median House Age):**
#
# - The distribution shows a peak around the median house age and tails off on both sides.
# - The kurtosis value might be slightly higher due to the tails, but it is likely to be relatively close to that of a normal distribution.
#
# **AveRooms (Average Rooms):**
#
# - The distribution appears to be positively skewed with a long tail on the right side.
# - The kurtosis value might be higher due to the presence of outliers causing a heavier tail.
#
# **AveBedrms (Average Bedrooms):**
#
# - The distribution is positively skewed, but it also seems to have a peak around lower values.
# - The kurtosis value might be influenced by the heavier tail on the right side and the peak on the left side.
#
# **Population:**
#
# - The distribution shows a peak around lower population values and tails off on the right side.
# - The kurtosis value might be slightly higher due to the tails and the potential presence of outliers.
#
# **AveOccup (Average Occupancy):**
#
# - The distribution is heavily skewed to the right, with a long tail.
# - The kurtosis value is likely to be significantly higher due to the very heavy tail.

# %% [markdown]
# ####  Breast Cancer Wisconsin (Diagnostic) dataset (commonly known as the "breast cancer dataset")

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import load_breast_cancer
from scipy.stats import kurtosis

# %%
# Load the breast cancer dataset
data = load_breast_cancer()
X, feature_names = data.data, data.feature_names

# %%
print(data.DESCR)
# Out:
# .. _breast_cancer_dataset:
#
# Breast cancer wisconsin (diagnostic) dataset
# --------------------------------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 569
#
#     :Number of Attributes: 30 numeric, predictive attributes and the class
#
#     :Attribute Information:
#         - radius (mean of distances from center to points on the perimeter)
#         - texture (standard deviation of gray-scale values)
#         - perimeter
#         - area
#         - smoothness (local variation in radius lengths)
#         - compactness (perimeter^2 / area - 1.0)
#         - concavity (severity of concave portions of the contour)
#         - concave points (number of concave portions of the contour)
#         - symmetry
#         - fractal dimension ("coastline approximation" - 1)
#
#         The mean, standard error, and "worst" or largest (mean of the three
#         worst/largest values) of these features were computed for each image,
# ...

# %%
# Create KDE plots and compute kurtosis
plt.figure(figsize=(18, 20))

for i in range(X.shape[1]):
    plt.subplot(5, 6, i + 1)  # Adjust this for the number of features
    sns.kdeplot(X[:, i], label=feature_names[i])
    plt.xlabel('Value')
    plt.ylabel('Density')
    plt.title('KDE Plot - ' + feature_names[i])
    plt.legend()

    # Compute kurtosis
    kurt = kurtosis(X[:, i])
    plt.text(0.95, 0.85, f'Kurtosis: {kurt:.2f}', transform=plt.gca().transAxes, verticalalignment='top', horizontalalignment='right')

plt.tight_layout()

# %% [markdown]
# ##### top 3 columns that are likely to have extreme values

# %% [markdown]
#  Higher kurtosis values often indicate the presence of heavy tails and potential extreme values.

# %%
# Load the breast cancer dataset
data = load_breast_cancer()
X, feature_names = data.data, data.feature_names

# Compute kurtosis for each column
kurtosis_values = [kurtosis(X[:, i]) for i in range(X.shape[1])]

# Sort columns by kurtosis values
sorted_indices = np.argsort(kurtosis_values)[::-1]

# Get the top 3 columns with the highest kurtosis values
top_indices = sorted_indices[:3]
top_columns = [feature_names[i] for i in top_indices]

print("Top 3 columns likely to have extreme values:")
for i, column in enumerate(top_columns, start=1):
    print(f"{i}. {column} (Kurtosis: {kurtosis_values[feature_names.tolist().index(column)]:.2f})")
# Out:
# Top 3 columns likely to have extreme values:
# 1. area error (Kurtosis: 48.77)
# 2. concavity error (Kurtosis: 48.42)
# 3. fractal dimension error (Kurtosis: 26.04)

# %% [markdown]
# #### Dispersion

# %%
# Sample dataset
data = np.array([12, 18, 25, 30, 32, 40, 50, 58, 60, 70])

# Range
data_range = np.max(data) - np.min(data)
print("Range:", data_range)

# Variance
data_variance = np.var(data)
print("Variance:", data_variance)

# Standard Deviation
data_std_deviation = np.sqrt(data_variance)
print("Standard Deviation:", data_std_deviation)

# Mean Absolute Deviation (MAD)
data_mean = np.mean(data)
data_mad = np.mean(np.abs(data - data_mean))
print("Mean Absolute Deviation (MAD):", data_mad)

# Interquartile Range (IQR)
data_quartiles = np.percentile(data, [25, 75])
data_iqr = data_quartiles[1] - data_quartiles[0]
print("Interquartile Range (IQR):", data_iqr)
# Out:
# Range: 58
# Variance: 337.85
# Standard Deviation: 18.38069639594757
# Mean Absolute Deviation (MAD): 16.1
# Interquartile Range (IQR): 29.75

# %% [markdown]
# ##### Apply IQR on CA housing dataset

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.datasets import fetch_california_housing

# %%
# Load California housing dataset
data = fetch_california_housing()
X, feature_names = data.data, data.feature_names

# %%
# Convert to DataFrame for better handling
housing_df = pd.DataFrame(X, columns=feature_names)

# %%
# Calculate quartiles and IQR for each column
Q1 = housing_df.quantile(0.25)
Q3 = housing_df.quantile(0.75)
IQR = Q3 - Q1

# %%
# Establish lower and higher cutoffs
lower_cutoff = Q1 - 1.5 * IQR
upper_cutoff = Q3 + 1.5 * IQR

# %%
# Extract outliers for each column
outliers = ((housing_df < lower_cutoff) | (housing_df > upper_cutoff))

# %%
# Create box plots for each column
plt.figure(figsize=(12, 6))
sns.boxplot(data=housing_df)
plt.xticks(rotation=45)
plt.title('Box Plots of CA Housing Dataset')
plt.xlabel('Features')
plt.ylabel('Values')
plt.tight_layout()
plt.show()

# %%
# Display column-wise outliers
print("Column-wise Outliers:")
for column in housing_df.columns:
    column_outliers = housing_df[column][outliers[column]]
    if not column_outliers.empty:
        print(f"{column} - Outliers:", column_outliers)

# Display lower and higher cutoffs
print("\nLower Cutoffs:")
print(lower_cutoff)
print("\nUpper Cutoffs:")
print(upper_cutoff)
# Out:
# Column-wise Outliers:
# MedInc - Outliers: 0         8.3252
# 1         8.3014
# 131      11.6017
# 134       8.2049
# 135       8.4010
#           ...
# 20426    10.0472
# 20427     8.6499
# 20428     8.7288
# 20436    12.5420
# 20503     8.2787
# Name: MedInc, Length: 681, dtype: float64
# AveRooms - Outliers: 73       1.714286
# 155      8.972868
# 511      8.928358
# 512      9.210227
# 514      9.122715
#            ...
# 20408    8.730038
# 20426    9.890756
# 20428    8.715842
# 20436    9.873315
# 20462    8.652174
# Name: AveRooms, Length: 511, dtype: float64
# AveBedrms - Outliers: 41       1.248996
# 57       1.372951
# 59       0.754386
# 61       1.260870
# 62       1.557377
#            ...
# 20423    1.505155
# 20608    1.273171
# 20620    0.854167
# 20621    1.573248
# 20636    1.315789
# Name: AveBedrms, Length: 1424, dtype: float64
# Population - Outliers: 95       3469.0
# 185      4367.0
# 283      4985.0
# 460      3337.0
# 485      3276.0
#           ...
# ...
