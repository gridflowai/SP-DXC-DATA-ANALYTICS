# %% [markdown]
# -------------------
# ### data symmetry
# - Using Normal distribution
# -----------------------

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns  # For density plots

# %%
# Generate some example data (replace this with your actual data)
np.random.seed(0)
data = np.random.normal(loc=5, scale=11, size=1000)

# %%
# Create a histogram
plt.figure(figsize=(12, 6))
plt.subplot(1, 3, 1)
plt.hist(data, bins=30, edgecolor='black', alpha=0.7)
plt.title('Histogram')

# Create a box plot
plt.subplot(1, 3, 2)
plt.boxplot(data, vert=False)
plt.title('Box Plot')

# Create a density plot
plt.subplot(1, 3, 3)
sns.kdeplot(data, fill=True)
plt.title('Density Plot')

plt.tight_layout()

# %% [markdown]
# **Example**

# %%
import pandas as pd
from sklearn.datasets import fetch_openml

# %%
# Load the California housing dataset
housing = fetch_openml(name="california_housing")
# Out:
# D:\anaconda\Lib\site-packages\sklearn\datasets\_openml.py:303: UserWarning: Multiple active versions of the dataset matching the name california_housing exist. Versions may be fundamentally different, returning version 1.
#   warn(
# D:\anaconda\Lib\site-packages\sklearn\datasets\_openml.py:1002: FutureWarning: The default value of `parser` will change from `'liac-arff'` to `'auto'` in 1.4. You can set `parser='auto'` to silence this warning. Therefore, an `ImportError` will be raised from 1.4 if the dataset is dense and pandas is not installed. Note that the pandas parser may return different data types. See the Notes Section in fetch_openml's API doc for details.
#   warn(

# %%
# Create a DataFrame from the dataset
df = pd.DataFrame(data=housing.data, columns=housing.feature_names)

# %%
df.sample(10)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 13262    -117.65     34.10                19.0       1688.0           365.0
# 4446     -118.21     34.07                31.0       1077.0           300.0
# 11371    -117.98     33.71                26.0       1905.0           373.0
# 12461    -121.43     38.58                35.0       5298.0           954.0
# 10487    -117.68     33.49                17.0       2232.0           372.0
# 9431     -122.96     38.26                20.0       1982.0           358.0
# 20344    -119.06     34.23                29.0       3511.0           632.0
# 2198     -119.88     36.85                 8.0       2580.0           372.0
# 20394    -118.87     34.22                14.0       3108.0           451.0
# 8269     -118.16     33.77                30.0       4439.0          1105.0
#
#        population  households  median_income ocean_proximity
# 13262       622.0       322.0         3.6000          INLAND
# 4446       1198.0       274.0         2.1333       <1H OCEAN
# 11371      1098.0       368.0         4.8611       <1H OCEAN
# 12461      1933.0       918.0         3.9167          INLAND
# 10487      1072.0       385.0         4.2450       <1H OCEAN
# 9431        308.0       132.0         3.1429      NEAR OCEAN
# 20344      2591.0       596.0         3.0219       <1H OCEAN
# 2198       1111.0       393.0         7.5000          INLAND
# 20394      1566.0       434.0         6.2423       <1H OCEAN
# 8269       1749.0      1011.0         3.8984      NEAR OCEAN

# %%
# Set up the subplots
fig, axes = plt.subplots(nrows=3, ncols=3, figsize=(12, 10))

# Plot the histograms and KDE plots
for i, col in enumerate(df.columns):
    ax = axes[i // 3, i % 3]
    sns.histplot(df[col], bins=30, kde=True, ax=ax)
    ax.set_xlabel(col)
    ax.set_ylabel('Frequency')

# Adjust layout and show the plots
plt.tight_layout()
plt.show()
